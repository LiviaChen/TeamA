# %%
# !pip install w3lib

# %%
# !pip install requests
# !pip install bs4

# %%
# !pip install pandas

# %%
# Out:
# 標題: 四大名師看好2021「元月行情」！外資將回補台股　資金轉入科技股
#
#
# 記者陳心怡／台北報導台股2020年上演大驚奇，雖受疫情拖累，3月一度重挫至8523點，但4月即重回萬點，下半年更不斷震盪衝高，封關日盤中更創下14760點歷史新高。展望2021年台股，4大名師認為，第1季可望延續資金行情，在外資回補、企業獲利成長下，台股有望再創新高，尤其1月是傳統的做夢行情，資金將從傳產流向盤整已久的科技類股。台新投顧研究部副總黃文清表示，相當看好2021年1月的股市，雖然2020年台股漲近23%，其中，半導體族群以及台積電貢獻相當多，但在11、 12月份表現強的都是傳產、原物料類股，然而1月陸陸續續都有不少科技大廠舉辦上半年度展望法說會以及公布第四季獲利，因此預計在1月初股市會先反應作夢行情，資金有望流回電子股。不過，目前類股輪動仍快，因此建議投資人操作上，漲多的個股不要追，如果出現拉回可逢低承接，手上有持股可續抱，整體股市在1月份還是有向上攻的機會。台新投顧總經理李鎮宇表示，雖然現在疫情有點嚴重，不過也不是全新病毒，市場還是認為最糟情況已過，加上資金持續寬鬆，且1月份都是傳統的電子股作夢行情，因此預估資金會從去年11、12月漲多的傳產類股，流向科技股，其中DRAM、被動元件、面板、IC設計都有機會。此外，李鎮宇指出，去年11、12月傳產股實在漲太急太兇，今年1月會稍微休息一陣子，不過疫情會隨著疫苗普及逐漸穩定可控，因此價值股長線趨勢還是會一直往上走。統一投顧董事長黎方國預期，台股會一路漲到2021年第一季。且外資2020年大幅賣超台股，按過過往經驗，外資未連續兩年賣超台股，因此預期2021年外資將恢復買超，第一季聚焦蘋概股、半導體、5G概念、汽車、電動車、基建等財報利多及4Q展望佳的業績題材股。華南投顧董事長儲祥生表示，外資動向向來是決定加權指數走勢關鍵，美股看起來強勢，且外資2020賣超台股，今年非常有機會回補，投資人可留意5G、WIFI6相關概念股，包括被動元件、散熱、PCB、IC族群，不過還是要留意不少電子股本益比都不是太便宜，能不能大漲還要觀察，拉回的話還是要小心斟酌佈局。
#
#  網址: https://www.ettoday.net/news/20210103/1890077.htm
#
#                                     2021-01-03 09:08
# =============
#
#
# 標題: 防陸科技滲透！　檢調進「台積電中科廠」出重手
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-05988032e7a0> in <module>
#      64             i = i.text
#      65             a = soup.findAll("div", {"class": "ad_readmore"})
# ---> 66             a = a[0].text
#      67             b = soup.select("strong")#圖片下的註解 #findAll不知道為啥不能用
#      68             b = b[0].text
#
# IndexError: list index out of range

# %%
import requests as rq
from bs4 import BeautifulSoup
import json
import pandas as pd
import os
import csv
import re
import time as t
import random
import lxml



userAgent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:82.0) Gecko/20100101 Firefox/82.0'
headers = {
    'User-Agent':userAgent
}
frame = ['標題','時間','網址','內容','產業類別','股票代號','股票名稱' ]
id = []
df = pd.DataFrame(frame, index = id)

j = 1

#以下為關鍵字
d = {}
with open("comp2.txt", 'r', encoding="utf8") as f:
    
    for line in f:
        
        (key, val) = line.split()
        a = val 
        d[str(val)] = a
values = list(d.values())

# print(values)


for c in values:#以下為關鍵字
#     print(c)
    search = c
    
    Url_Input = 'https://www.ettoday.net/news_search/doSearch.php?search_term_string='+search
#     print(Url_Input)
    url = Url_Input
    #以下為股票編號
    l = {}
    with open("comp2.txt", 'r', encoding="utf8") as f:
        for line in f:
            (key, val) = line.split()
            l[int(key)] = a
            keys = list(l.keys())
        # print(keys)

    for k in keys:
#         print(k)
        
        #以下為產業類別
        C = {}
        with open("compCat.txt", 'r', encoding="utf8") as Cat:
            for kat in Cat:
#             print(kat)
    


                for i in range(0, 10):
                    res = rq.get(url, headers=headers)
                    soup = BeautifulSoup(res.text, 'html.parser')
                    temp = []#設定一個字典
                    p=0
                    newUrl = soup.select("div.menu_page a")[-2]["href"]

                    titles = soup.select('div.box_2')
                #     titleUrl =
                    for i in range(7, 37, 3): #這裡開始照著網址的順序抓
                        titleUrl = soup.select('a')[i]['href']
                        temp.append(titleUrl)#每次會把新的網址丟到字典裡
                    for titleTag in titles:#這裡開始抓標題
                        title = titleTag.select_one('a')
                    #開始抓內文
                        res = rq.get(temp[p], headers=headers)
                        soup = BeautifulSoup(res.text, 'html.parser')
                        time = soup.findAll("time", {"class":"date"})
                        time = time[0].text




                        print('產業類別:', kat)#產業類別
                        print('股票編號:', k)#股票編號
                        print("標題:", title.text)
                        print('\n')

                #         print(content)


                        for i in soup.findAll("div", {"class": "story"}):            
                            i = i.text
                            try:
                                a = soup.findAll("div", {"class": "ad_readmore"})
                                a = a[0].text
                            except IndexError:
                                pass

                            try:
                                b = soup.select("strong")#圖片下的註解 #findAll不知道為啥不能用
                                b = b[0].text
                            except IndexError:
                                pass
                            result = (i.replace(str(a), ''))#去除廣告字串
                #             print(result.replace('\n',''))#把換行用掉
                            result2 = result.replace('\n','')
                            content = result2.replace(str(b), '')
                            print(content)#內文
                            #以下為時間
#                             df.loc[J] = [time, kat, k, values, title.text, temp[p], content]
#                             df.to_csv('TeamAone.csv', index = False, encoding = 'utf_8_sig')
#                             J +=1

                #             print(a)
                        



                        print('\n', '網址:', temp[p])#印出網址字典的內容
                        p+=1#下次會印出下一筆
                        print(time)
                        print('=============')
                        print('\n')

#                         df.loc[J] = [time, kat, k, values, title.text, temp[p], content]
#                         df.to_csv('TeamAone2.csv', index = False, encoding = 'utf_8_sig')# !!list if index out of range
#                         J +=1

                #         print(titleUrl)

                            
                    url = newUrl
                #     print(newUrl)
                    sleep_time = random.randint(3,10)
                    sl = sleep_time
                    print("sleep time: %s sec"%(sleep_time))
                    t.sleep(sl)
                    j +=1
                    print(df)
                    
                    df.loc[j] = [title, time, temp[p], content, kat, k, values]
                    
                    df.to_csv('TeamAone.csv', index = 0, encoding = 'utf_8_sig')
#                     df.loc[J] = [title, time, temp[p], content, kat, k, values]
#                     df.to_csv('TeamAone.csv', index = 0, encoding = 'utf_8_sig')
#                     J +=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\Practice\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1679
# -> 1680         mgr = BlockManager(blocks, axes)
#    1681         mgr._consolidate_inplace()
#
# ~\anaconda3\envs\Practice\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     142         if do_integrity_check:
# --> 143             self._verify_integrity()
#     144
#
# ~\anaconda3\envs\Practice\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     322             if block.shape[1:] != mgr_shape[1:]:
# --> 323                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     324         if len(self.items) != tot_items:
#
# ValueError: Shape of passed values is (7, 1), indices imply (0, 1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-ec7d912c8274> in <module>
#      18 frame = ['標題','時間','網址','內容','產業類別','股票代號','股票名稱' ]
#      19 id = []
# ---> 20 df = pd.DataFrame(frame, index=id)
#      21
#      22 j = 1
#
# ~\anaconda3\envs\Practice\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     582                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     583                 else:
# --> 584                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     585             else:
#     586                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# ~\anaconda3\envs\Practice\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     236         block_values = [values]
#     237
# --> 238     return create_block_manager_from_blocks(block_values, [columns, index])
#     239
#     240
#
# ~\anaconda3\envs\Practice\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1685         blocks = [getattr(b, "values", b) for b in blocks]
#    1686         tot_items = sum(b.shape[0] for b in blocks)
# -> 1687         raise construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1688
#    1689
#
# ValueError: Shape of passed values is (7, 1), indices imply (0, 1)
