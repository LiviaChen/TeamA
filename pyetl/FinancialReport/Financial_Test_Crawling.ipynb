# %% [markdown]
# # 個股

# %%
# !pip3 install lxml
# !pip install html5lib

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import random
import os 



# 爬取網站
year = 108
season = 4
stock_number = 2701
tourism_stocks = (2701,2702,2704,2705,2706,2707,2712,2722,2723,2727,2731,2739,2748,5706,8462,8940,9943)
Biotechnology_stocks = (1598,1701,1707,1720,1731,1733,1734,1736,1760,1762,1783,1786,1789,1795,3164,3705,4104,4106,4108,4119,4133,4137,4141,4142,4148,4155,4164,4190,4737,4746,6491,6541,6598,6666)

BalanceSheetURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb03";      # 資產負債表
ProfitAndLoseURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb04";     # 損益表
CashFlowStatementURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb05"; # 現金流量表


# Headers
headers = {
    'Connection': 'keep-alive',
    'Content-Length': '160',
    'Content-Type': 'application/x-www-form-urlencoded',
    'Host': 'mops.twse.com.tw',
    'Origin': 'https://mops.twse.com.tw',
    'Referer': 'https://mops.twse.com.tw/mops/web/t164sb04',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'
}

###
### Crawl One index
###

def crawlone_financial_report(url):
    
    form_data = {
        'encodeURIComponent':1,
        'step':1,
        'firstin':1,
        'off':1,
        'co_id':stock_number,
        'year': year,
        'season': season,
    }

    r = requests.post(url,form_data, headers = headers)
    html_df = pd.read_html(r.text)[1].fillna("")
    return html_df

###
### In Developing
###

def crawlmany_financial_report(url):
    

    dflist = crawlone_financial_report(BalanceSheetURL)
    
    try:
        
        for stock_number in (2701,2702,2704,2705,2706,2707,2712,2722,2723,2727,2731,2739,2748,5706,8462,8940,9943):
            for year in range(105, 110):
                for season in range(1, 5):

                    html_df = []
#                     title_row = pd.DataFrame((['{}'.format(stock)number]),)
                    form_data = {
                        'encodeURIComponent':1,
                        'step':1,
                        'firstin':1,
                        'off':1,
                        'co_id':stock_number,
                        'year': year,
                        'season': season,
                    } 
                    
                    r = requests.post(url,form_data, headers = headers)
                    html_df = pd.read_html(r.text)[1].fillna("")
                    dflist = dflist.append(html_df, ignore_index=False)

                    sleep_time = random.randint(2, 4)
                    time.sleep(sleep_time)
                    print(dflist)

    except ValueError:
        print('')
    except NameError:
        print('')
    
    if os.path.exists('./{}.csv'.format('Fn_Report')): 
        os.remove('./{}.csv'.format('Fn_Report'))
        dflist.to_csv('./{}.csv'.format('Fn_Report'), index=0, encoding='utf-8-sig')
    else:
        dflist.to_csv('./{}.csv'.format('Fn_Report'), index=0, encoding='utf-8-sig')
    return dflist

# %%
# crawlone_financial_report(BalanceSheetURL)
crawlmany_financial_report(BalanceSheetURL)
# Out:
#     民國108年第1季                                                         \
#      單位：新台幣仟元
#    107年03月31日            107年12月31日            108年03月31日
#             %         金額          %         金額          %         金額
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
# ..        ...        ...        ...        ...        ...        ...
# 43      86.05  7065920.0      85.95  7392488.0      85.85  7492991.0
# 44     100.00  8211434.0     100.00  8601032.0     100.00  8728322.0
# 45                   0.0                   0.0                   0.0
# 46                   0.0                   0.0                   0.0
# ...

# %% [markdown]
# # Testing Area

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import random
import os 



# 爬取網站
year = 108
season = 4
stock_number = 2701
tourism_stocks = (2701,2702,2704,2705,2706,2707,2712,2722,2723,2727,2731,2739,2748,5706,8462,8940,9943)
Biotechnology_stocks = (1598,1701,1707,1720,1731,1733,1734,1736,1760,1762,1783,1786,1789,1795,3164,3705,4104,4106,4108,4119,4133,4137,4141,4142,4148,4155,4164,4190,4737,4746,6491,6541,6598,6666)

BalanceSheetURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb03";      # 資產負債表
ProfitAndLoseURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb04";     # 損益表
CashFlowStatementURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb05"; # 現金流量表


# Headers
headers = {
    'Connection': 'keep-alive',
    'Content-Length': '160',
    'Content-Type': 'application/x-www-form-urlencoded',
    'Host': 'mops.twse.com.tw',
    'Origin': 'https://mops.twse.com.tw',
    'Referer': 'https://mops.twse.com.tw/mops/web/t164sb04',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'
}

###
### Crawl One index
###

def crawlone_financial_report(url):
    
    form_data = {
        'encodeURIComponent':1,
        'step':1,
        'firstin':1,
        'off':1,
        'co_id':stock_number,
        'year': year,
        'season': season,
    }

    r = requests.post(url,form_data, headers = headers)
    html_df = pd.read_html(r.text)[1].fillna("")
    return html_df

###
### In Developing
###

def crawlmany_financial_report(url):
    

    dflist = crawlone_financial_report(BalanceSheetURL)
    
    try:
        
        for stock_number in (2701,2702,2704,2705,2706,2707,2712,2722,2723,2727,2731,2739,2748,5706,8462,8940,9943):
            for year in range(108, 109):
                for season in range(1, 5):

                    html_df = []
                    form_data = {
                        'encodeURIComponent':1,
                        'step':1,
                        'firstin':1,
                        'off':1,
                        'co_id':stock_number,
                        'year': year,
                        'season': season,
                    } 
                    r = requests.post(url,form_data, headers = headers)
                    html_df = pd.read_html(r.text)[1].fillna("")
                    dflist = dflist.append(html_df, ignore_index=False)

                    sleep_time = random.randint(2, 4)
                    time.sleep(sleep_time)
                    print(dflist)

    except ValueError:
        print('')
    except NameError:
        print('')
    
    if os.path.exists('./{}.csv'.format('Fn_Report')): 
        os.remove('./{}.csv'.format('Fn_Report'))
        dflist.to_csv('./{}.csv'.format('Fn_Report'), index=0, encoding='utf-8-sig')
    else:
        dflist.to_csv('./{}.csv'.format('Fn_Report'), index=0, encoding='utf-8-sig')
    return dflist

# %%
for stock_number in (2701,2702,2704,2705,2706,2707,2712,2722,2723):
    for year in range(109, 110):
        for season in range(1, 5):

            html_df = []
            form_data = {
                'encodeURIComponent':1,
                'step':1,
                'firstin':1,
                'off':1,
                'co_id':stock_number,
                'year': year,
                'season': season,
            } 
            print(form_data)
# Out:
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 2701, 'year': 109, 'season': 1}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 2701, 'year': 109, 'season': 2}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 2701, 'year': 109, 'season': 3}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 2701, 'year': 109, 'season': 4}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 2702, 'year': 109, 'season': 1}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 2702, 'year': 109, 'season': 2}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 2702, 'year': 109, 'season': 3}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 2702, 'year': 109, 'season': 4}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 2704, 'year': 109, 'season': 1}
# ...
