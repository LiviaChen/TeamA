# %%
# !pip3 install lxml

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import random
import os 


# 爬取網站
year = 107
season = 4
stock_number = 1101

BalanceSheetURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb03";      # 資產負債表
ProfitAndLoseURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb04";     # 損益表
CashFlowStatementURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb05"; # 現金流量表


# Headers
headers = {
    'Connection': 'keep-alive',
    'Content-Length': '160',
    'Content-Type': 'application/x-www-form-urlencoded',
    'Host': 'mops.twse.com.tw',
    'Origin': 'https://mops.twse.com.tw',
    'Referer': 'https://mops.twse.com.tw/mops/web/t164sb04',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'
}

###
### Crawl One index
###

def crawlone_Financial_Report(url):
    
    form_data = {
        'encodeURIComponent':1,
        'step':1,
        'firstin':1,
        'off':1,
        'co_id':stock_number,
        'year': year,
        'season': season,
    }

    r = requests.post(url,form_data, headers = headers)
    html_df = pd.read_html(r.text)[1].fillna("")
    if os.path.exists('D:/Topic/FinancialReport/{}.csv'.format('Fn_Report')): 
        os.remove('D:/Topic/FinancialReport/{}.csv'.format('Fn_Report'))
    else:
        html_df.to_csv('D:/Topic/FinancialReport/{}.csv'.format('Fn_Report'), index=0, encoding='utf-8-sig')
    return html_df

###
### In Developing
###

def crawlmany_Financial_Report(url):
     for year in range(107, 110):
        for season in range(1, 5):
            form_data = {
                'encodeURIComponent':1,
                'step':1,
                'firstin':1,
                'off':1,
                'co_id':stock_number,
                'year': year,
                'season': season,
            }
            
        r = requests.post(url,form_data, headers = headers)
        html_df = pd.read_html(r.text)[1].fillna("")
    
    
        if os.path.exists('D:/Topic/FinancialReport/{}.csv'.format('Fn_Report')): 
            os.remove('D:/Topic/FinancialReport/{}.csv'.format('Fn_Report'))
        else:
            html_df.to_csv('D:/Topic/FinancialReport/{}.csv'.format('Fn_Report'), index=0, encoding='utf-8-sig')
        return html_df


        sleep_time = random.randint(6, 10)
        time.sleep(sleep_time)

# %%
crawlone_financial_Report(BalanceSheetURL)
# crawl_csv(BalanceSheetURL)
# Out:
#                     民國107年第4季                                            \
#                      單位：新台幣仟元
#                          會計項目   107年12月31日           106年12月31日
#            Unnamed: 0_level_3           金額       %           金額       %
# 0                        流動資產
# 1                     現金及約當現金   48507889.0   14.10   26331218.0    9.66
# 2         透過損益按公允價值衡量之金融資產－流動     549838.0    0.16     147049.0    0.05
# 3     透過其他綜合損益按公允價值衡量之金融資產－流動    6334259.0    1.84          0.0    0.00
# 4               備供出售金融資產－流動淨額          0.0    0.00   25101220.0    9.21
# 5          按攤銷後成本衡量之金融資產－流動淨額    2664157.0    0.77          0.0    0.00
# 6                      應收票據淨額   29748544.0    8.65   20003996.0    7.34
# 7                      應收帳款淨額    8216174.0    2.39    7072466.0    2.59
# 8                  應收帳款－關係人淨額     271618.0    0.08     229702.0    0.08
# 9                     其他應收款淨額     955814.0    0.28     751932.0    0.28
# ...

# %% [markdown]
# # Testing Area

# %%
for loop in 
    for year in range(107, 110):
        for season in range(1, 5):
        
            form_data = {
                'encodeURIComponent':1,
                'step':1,
                'firstin':1,
                'off':1,
                'co_id':stock_number,
                'year': year,
                'season': season,
            }
            print(form_data)
# Out:
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 1101, 'year': 107, 'season': 1}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 1101, 'year': 107, 'season': 2}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 1101, 'year': 107, 'season': 3}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 1101, 'year': 107, 'season': 4}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 1101, 'year': 108, 'season': 1}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 1101, 'year': 108, 'season': 2}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 1101, 'year': 108, 'season': 3}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 1101, 'year': 108, 'season': 4}
# {'encodeURIComponent': 1, 'step': 1, 'firstin': 1, 'off': 1, 'co_id': 1101, 'year': 109, 'season': 1}
# ...
